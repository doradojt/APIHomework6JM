# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key

from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 637

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city_test = "New York"
test_url = f"{url}appid={api_key}&q={city_test}"

print(test_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=63395cbd4305b5463c2d303a007dede5&q=New York

# %%
cities_df = pd.DataFrame(cities)
cities_df = cities_df.rename(columns={0 : "Name"})
#cities_df

# %%
# set up additional columns to hold information

cities_df['country'] = ""
cities_df['latitude'] = ""
cities_df['longitude'] = ""
cities_df['max temperature'] = ""
cities_df['cloudiness'] = ""
cities_df['date'] = ""
cities_df['humidity'] = ""
cities_df['wind speed'] = ""


#cities_df

# %%
base_url = f"{url}appid={api_key}&q=" 


print("Beginning Data Retrieval")
print("------------------------")

for index, row in cities_df.iterrows():
    
    city_data = row["Name"]
    
    time.sleep(1)
    
    city_response = requests.get(base_url + city_data).json()
    
    try:
        print(f"Processing Record {index} of Set {index} | {city_data}")
        cities_df.loc[index, 'country'] = city_response['sys']['country']
        cities_df.loc[index, 'latitude'] = city_response['coord']['lat']
        cities_df.loc[index, 'longitude'] = city_response['coord']['lon']
        cities_df.loc[index, 'max temperature'] = city_response['main']['temp_max']
        cities_df.loc[index, 'cloudiness'] = city_response['clouds']['all']
        cities_df.loc[index, 'date'] = city_response['dt']
        cities_df.loc[index, 'humidity'] = city_response['main']['humidity']
        cities_df.loc[index, 'wind speed'] = city_response['wind']['speed']
    except KeyError:
        print("City not found. Skipping....")

print("Done")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 0 | mataura
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 2 | tekeli
# Processing Record 3 of Set 3 | saint-augustin
# Processing Record 4 of Set 4 | bredasdorp
# Processing Record 5 of Set 5 | poum
# Processing Record 6 of Set 6 | cherskiy
# Processing Record 7 of Set 7 | barentsburg
# City not found. Skipping....
# Processing Record 8 of Set 8 | wakkanai
# Processing Record 9 of Set 9 | port hawkesbury
# Processing Record 10 of Set 10 | mullaitivu
# City not found. Skipping....
# Processing Record 11 of Set 11 | san benito
# Processing Record 12 of Set 12 | punta arenas
# Processing Record 13 of Set 13 | busselton
# Processing Record 14 of Set 14 | isangel
# Processing Record 15 of Set 15 | vaini
# Processing Record 16 of Set 16 | carnarvon
# Processing Record 17 of Set 17 | ambilobe
# Processing Record 18 of Set 18 | albany
# Processing Record 19 of Set 19 | rikitea
# Processing Record 20 of Set 20 | qaanaaq
# Processing Record 21 of Set 21 | victoria
# Processing Record 22 of Set 22 | mudyuga
# City not found. Skipping....
# Processing Record 23 of Set 23 | charlottesville
# Processing Record 24 of Set 24 | vila franca do campo
# Processing Record 25 of Set 25 | gabrovo
# Processing Record 26 of Set 26 | upernavik
# Processing Record 27 of Set 27 | bluff
# Processing Record 28 of Set 28 | hilo
# Processing Record 29 of Set 29 | vila velha
# Processing Record 30 of Set 30 | new norfolk
# Processing Record 31 of Set 31 | balite
# Processing Record 32 of Set 32 | riyadh
# Processing Record 33 of Set 33 | thompson
# Processing Record 34 of Set 34 | samalaeulu
# City not found. Skipping....
# Processing Record 35 of Set 35 | mahebourg
# Processing Record 36 of Set 36 | katobu
# Processing Record 37 of Set 37 | dikson
# Processing Record 38 of Set 38 | kamina
# Processing Record 39 of Set 39 | mabaruma
# Processing Record 40 of Set 40 | padang
# Processing Record 41 of Set 41 | port hedland
# Processing Record 42 of Set 42 | kapaa
# Processing Record 43 of Set 43 | tiksi
# Processing Record 44 of Set 44 | tuktoyaktuk
# Processing Record 45 of Set 45 | atuona
# Processing Record 46 of Set 46 | baghdad
# Processing Record 47 of Set 47 | alekseyevsk
# Processing Record 48 of Set 48 | igarka
# Processing Record 49 of Set 49 | marsabit
# Processing Record 50 of Set 50 | coihaique
# Processing Record 51 of Set 51 | rialma
# Processing Record 52 of Set 52 | mudgee
# Processing Record 53 of Set 53 | illoqqortoormiut
# City not found. Skipping....
# Processing Record 54 of Set 54 | khatanga
# Processing Record 55 of Set 55 | lagoa
# Processing Record 56 of Set 56 | samusu
# City not found. Skipping....
# Processing Record 57 of Set 57 | cape town
# Processing Record 58 of Set 58 | kaeo
# Processing Record 59 of Set 59 | ucluelet
# Processing Record 60 of Set 60 | opuwo
# Processing Record 61 of Set 61 | hobart
# Processing Record 62 of Set 62 | bereda
# Processing Record 63 of Set 63 | gari
# Processing Record 64 of Set 64 | faanui
# Processing Record 65 of Set 65 | malwan
# City not found. Skipping....
# Processing Record 66 of Set 66 | nikolskoye
# Processing Record 67 of Set 67 | kahului
# Processing Record 68 of Set 68 | jamestown
# Processing Record 69 of Set 69 | myingyan
# Processing Record 70 of Set 70 | raduzhnyy
# Processing Record 71 of Set 71 | bambous virieux
# Processing Record 72 of Set 72 | biggar
# Processing Record 73 of Set 73 | cairns
# Processing Record 74 of Set 74 | port alfred
# Processing Record 75 of Set 75 | severo-kurilsk
# Processing Record 76 of Set 76 | mys shmidta
# City not found. Skipping....
# Processing Record 77 of Set 77 | faya
# Processing Record 78 of Set 78 | georgetown
# Processing Record 79 of Set 79 | ushuaia
# Processing Record 80 of Set 80 | mosquera
# Processing Record 81 of Set 81 | lebu
# Processing Record 82 of Set 82 | natal
# Processing Record 83 of Set 83 | vereeniging
# Processing Record 84 of Set 84 | hobyo
# Processing Record 85 of Set 85 | kaliua
# Processing Record 86 of Set 86 | chokurdakh
# Processing Record 87 of Set 87 | banamba
# Processing Record 88 of Set 88 | esperance
# Processing Record 89 of Set 89 | alice springs
# Processing Record 90 of Set 90 | clyde river
# Processing Record 91 of Set 91 | matara
# Processing Record 92 of Set 92 | taolanaro
# City not found. Skipping....
# Processing Record 93 of Set 93 | turayf
# Processing Record 94 of Set 94 | porto belo
# Processing Record 95 of Set 95 | avarua
# Processing Record 96 of Set 96 | salalah
# Processing Record 97 of Set 97 | boende
# Processing Record 98 of Set 98 | cayenne
# Processing Record 99 of Set 99 | belushya guba
# City not found. Skipping....
# Processing Record 100 of Set 100 | louisbourg
# City not found. Skipping....
# Processing Record 101 of Set 101 | popondetta
# Processing Record 102 of Set 102 | seddon
# Processing Record 103 of Set 103 | mago
# Processing Record 104 of Set 104 | gazli
# Processing Record 105 of Set 105 | jalu
# Processing Record 106 of Set 106 | slobozia
# Processing Record 107 of Set 107 | magistralnyy
# Processing Record 108 of Set 108 | mergui
# City not found. Skipping....
# Processing Record 109 of Set 109 | tasiilaq
# Processing Record 110 of Set 110 | abu samrah
# Processing Record 111 of Set 111 | springdale
# Processing Record 112 of Set 112 | cidreira
# Processing Record 113 of Set 113 | araouane
# Processing Record 114 of Set 114 | llanes
# Processing Record 115 of Set 115 | qasigiannguit
# Processing Record 116 of Set 116 | carnduff
# Processing Record 117 of Set 117 | port blair
# Processing Record 118 of Set 118 | guerrero negro
# Processing Record 119 of Set 119 | belgrade
# Processing Record 120 of Set 120 | chuy
# Processing Record 121 of Set 121 | leesburg
# Processing Record 122 of Set 122 | provideniya
# Processing Record 123 of Set 123 | mayo
# Processing Record 124 of Set 124 | beruwala
# Processing Record 125 of Set 125 | port lincoln
# Processing Record 126 of Set 126 | nanortalik
# Processing Record 127 of Set 127 | sola
# Processing Record 128 of Set 128 | saint george
# Processing Record 129 of Set 129 | katsuura
# Processing Record 130 of Set 130 | hirosaki
# Processing Record 131 of Set 131 | mareeba
# Processing Record 132 of Set 132 | ballina
# Processing Record 133 of Set 133 | dourados
# Processing Record 134 of Set 134 | kankaanpaa
# Processing Record 135 of Set 135 | trincomalee
# Processing Record 136 of Set 136 | northam
# Processing Record 137 of Set 137 | bowen
# Processing Record 138 of Set 138 | altay
# Processing Record 139 of Set 139 | nizhneyansk
# City not found. Skipping....
# Processing Record 140 of Set 140 | troitsko-pechorsk
# Processing Record 141 of Set 141 | te anau
# Processing Record 142 of Set 142 | oyem
# Processing Record 143 of Set 143 | amderma
# City not found. Skipping....
# Processing Record 144 of Set 144 | cabo san lucas
# Processing Record 145 of Set 145 | attawapiskat
# City not found. Skipping....
# Processing Record 146 of Set 146 | phangnga
# Processing Record 147 of Set 147 | tabiauea
# City not found. Skipping....
# Processing Record 148 of Set 148 | puerto ayora
# Processing Record 149 of Set 149 | hermanus
# Processing Record 150 of Set 150 | lumeje
# Processing Record 151 of Set 151 | awash
# Processing Record 152 of Set 152 | vestmanna
# Processing Record 153 of Set 153 | impfondo
# Processing Record 154 of Set 154 | whitecourt
# Processing Record 155 of Set 155 | takoradi
# Processing Record 156 of Set 156 | tibiao
# Processing Record 157 of Set 157 | sentyabrskiy
# City not found. Skipping....
# Processing Record 158 of Set 158 | saskylakh
# Processing Record 159 of Set 159 | sriperumbudur
# Processing Record 160 of Set 160 | snezhnogorsk
# Processing Record 161 of Set 161 | kafanchan
# Processing Record 162 of Set 162 | kungurtug
# Processing Record 163 of Set 163 | naryan-mar
# Processing Record 164 of Set 164 | kilindoni
# Processing Record 165 of Set 165 | derzhavinsk
# Processing Record 166 of Set 166 | hay river
# Processing Record 167 of Set 167 | beringovskiy
# Processing Record 168 of Set 168 | ilulissat
# Processing Record 169 of Set 169 | kapit
# Processing Record 170 of Set 170 | sao jose do calcado
# Processing Record 171 of Set 171 | laguna
# Processing Record 172 of Set 172 | nemuro
# Processing Record 173 of Set 173 | yangambi
# Processing Record 174 of Set 174 | aksarka
# Processing Record 175 of Set 175 | meulaboh
# Processing Record 176 of Set 176 | awbari
# Processing Record 177 of Set 177 | atyrau
# Processing Record 178 of Set 178 | antequera
# Processing Record 179 of Set 179 | blackwater
# Processing Record 180 of Set 180 | kalemie
# Processing Record 181 of Set 181 | kodiak
# Processing Record 182 of Set 182 | mattru
# Processing Record 183 of Set 183 | yulara
# Processing Record 184 of Set 184 | khuzhir
# Processing Record 185 of Set 185 | georgiyevka
# Processing Record 186 of Set 186 | cocachacra
# Processing Record 187 of Set 187 | guaraniacu
# Processing Record 188 of Set 188 | gurskoye
# City not found. Skipping....
# Processing Record 189 of Set 189 | braganca
# Processing Record 190 of Set 190 | sao jose da coroa grande
# Processing Record 191 of Set 191 | castro
# Processing Record 192 of Set 192 | paris
# Processing Record 193 of Set 193 | boguchany
# Processing Record 194 of Set 194 | khandyga
# Processing Record 195 of Set 195 | naze
# Processing Record 196 of Set 196 | maarianhamina
# City not found. Skipping....
# Processing Record 197 of Set 197 | astakos
# Processing Record 198 of Set 198 | pasighat
# Processing Record 199 of Set 199 | dubrovnik
# Processing Record 200 of Set 200 | kruisfontein
# Processing Record 201 of Set 201 | batagay-alyta
# Processing Record 202 of Set 202 | kikwit
# Processing Record 203 of Set 203 | touros
# Processing Record 204 of Set 204 | mar del plata
# Processing Record 205 of Set 205 | east london
# Processing Record 206 of Set 206 | abu kamal
# Processing Record 207 of Set 207 | sakaiminato
# Processing Record 208 of Set 208 | longyearbyen
# Processing Record 209 of Set 209 | daru
# Processing Record 210 of Set 210 | pedasi
# Processing Record 211 of Set 211 | tuatapere
# Processing Record 212 of Set 212 | tabas
# Processing Record 213 of Set 213 | pevek
# Processing Record 214 of Set 214 | lata
# Processing Record 215 of Set 215 | ovre ardal
# Processing Record 216 of Set 216 | hami
# Processing Record 217 of Set 217 | airai
# Processing Record 218 of Set 218 | pacific grove
# Processing Record 219 of Set 219 | bethel
# Processing Record 220 of Set 220 | borujerd
# Processing Record 221 of Set 221 | nome
# Processing Record 222 of Set 222 | sao filipe
# Processing Record 223 of Set 223 | ust-maya
# Processing Record 224 of Set 224 | butaritari
# Processing Record 225 of Set 225 | lolua
# City not found. Skipping....
# Processing Record 226 of Set 226 | nur
# Processing Record 227 of Set 227 | matadi
# Processing Record 228 of Set 228 | san carlos de bariloche
# Processing Record 229 of Set 229 | marsh harbour
# Processing Record 230 of Set 230 | songea
# Processing Record 231 of Set 231 | portland
# Processing Record 232 of Set 232 | kamenskoye
# City not found. Skipping....
# Processing Record 233 of Set 233 | port elizabeth
# Processing Record 234 of Set 234 | sorvag
# City not found. Skipping....
# Processing Record 235 of Set 235 | marcona
# City not found. Skipping....
# Processing Record 236 of Set 236 | karamea
# City not found. Skipping....
# Processing Record 237 of Set 237 | havoysund
# Processing Record 238 of Set 238 | batagay
# Processing Record 239 of Set 239 | ola
# Processing Record 240 of Set 240 | guderup
# Processing Record 241 of Set 241 | ponnani
# Processing Record 242 of Set 242 | pangnirtung
# Processing Record 243 of Set 243 | kasongo-lunda
# Processing Record 244 of Set 244 | sirjan
# Processing Record 245 of Set 245 | vaitupu
# City not found. Skipping....
# Processing Record 246 of Set 246 | alexandria
# Processing Record 247 of Set 247 | asfi
# City not found. Skipping....
# Processing Record 248 of Set 248 | sao miguel
# Processing Record 249 of Set 249 | eldoret
# Processing Record 250 of Set 250 | lerwick
# Processing Record 251 of Set 251 | qarqin
# Processing Record 252 of Set 252 | mokshan
# Processing Record 253 of Set 253 | sarangani
# Processing Record 254 of Set 254 | dalvik
# Processing Record 255 of Set 255 | whitehorse
# Processing Record 256 of Set 256 | ewo
# Processing Record 257 of Set 257 | tanout
# Processing Record 258 of Set 258 | tikheron
# City not found. Skipping....
# Processing Record 259 of Set 259 | ribeira grande
# Processing Record 260 of Set 260 | saint-philippe
# Processing Record 261 of Set 261 | fort nelson
# Processing Record 262 of Set 262 | dryden
# Processing Record 263 of Set 263 | marrakesh
# Processing Record 264 of Set 264 | samarai
# Processing Record 265 of Set 265 | san quintin
# Processing Record 266 of Set 266 | sao bernardo do campo
# Processing Record 267 of Set 267 | teyateyaneng
# Processing Record 268 of Set 268 | luderitz
# Processing Record 269 of Set 269 | kipini
# Processing Record 270 of Set 270 | ambon
# Processing Record 271 of Set 271 | moissala
# Processing Record 272 of Set 272 | forestville
# Processing Record 273 of Set 273 | ishinomaki
# Processing Record 274 of Set 274 | petropavl
# Processing Record 275 of Set 275 | souillac
# Processing Record 276 of Set 276 | wukari
# Processing Record 277 of Set 277 | bandarban
# Processing Record 278 of Set 278 | devli
# Processing Record 279 of Set 279 | pitea
# Processing Record 280 of Set 280 | knysna
# Processing Record 281 of Set 281 | koslan
# Processing Record 282 of Set 282 | kuche
# City not found. Skipping....
# Processing Record 283 of Set 283 | geraldton
# Processing Record 284 of Set 284 | barrow
# Processing Record 285 of Set 285 | mahibadhoo
# Processing Record 286 of Set 286 | kushima
# Processing Record 287 of Set 287 | high rock
# Processing Record 288 of Set 288 | hualmay
# Processing Record 289 of Set 289 | muisne
# Processing Record 290 of Set 290 | iskateley
# Processing Record 291 of Set 291 | taywarah
# Processing Record 292 of Set 292 | eldikan
# City not found. Skipping....
# Processing Record 293 of Set 293 | capreol
# Processing Record 294 of Set 294 | palabuhanratu
# City not found. Skipping....
# Processing Record 295 of Set 295 | mezen
# Processing Record 296 of Set 296 | ponta do sol
# Processing Record 297 of Set 297 | mae tha
# Processing Record 298 of Set 298 | khem karan
# Processing Record 299 of Set 299 | vostok
# Processing Record 300 of Set 300 | kyra
# City not found. Skipping....
# Processing Record 301 of Set 301 | naica
# Processing Record 302 of Set 302 | brovary
# Processing Record 303 of Set 303 | torbay
# Processing Record 304 of Set 304 | san policarpo
# Processing Record 305 of Set 305 | yellowknife
# Processing Record 306 of Set 306 | paragominas
# Processing Record 307 of Set 307 | hornepayne
# Processing Record 308 of Set 308 | zhigansk
# Processing Record 309 of Set 309 | saint-joseph
# Processing Record 310 of Set 310 | taoudenni
# Processing Record 311 of Set 311 | kloulklubed
# Processing Record 312 of Set 312 | buraydah
# Processing Record 313 of Set 313 | namibe
# Processing Record 314 of Set 314 | mitsamiouli
# Processing Record 315 of Set 315 | letnik
# Processing Record 316 of Set 316 | masyaf
# Processing Record 317 of Set 317 | gamba
# Processing Record 318 of Set 318 | krasnoyarka
# Processing Record 319 of Set 319 | kavieng
# Processing Record 320 of Set 320 | grindavik
# Processing Record 321 of Set 321 | rocha
# Processing Record 322 of Set 322 | kavaratti
# Processing Record 323 of Set 323 | makakilo city
# Processing Record 324 of Set 324 | erenhot
# Processing Record 325 of Set 325 | skibbereen
# Processing Record 326 of Set 326 | tubruq
# City not found. Skipping....
# Processing Record 327 of Set 327 | saldanha
# Processing Record 328 of Set 328 | cap malheureux
# Processing Record 329 of Set 329 | adelaide
# Processing Record 330 of Set 330 | curaca
# Processing Record 331 of Set 331 | hofn
# Processing Record 332 of Set 332 | batticaloa
# Processing Record 333 of Set 333 | cravo norte
# Processing Record 334 of Set 334 | hirara
# Processing Record 335 of Set 335 | sur
# Processing Record 336 of Set 336 | haines junction
# Processing Record 337 of Set 337 | kutum
# Processing Record 338 of Set 338 | mahon
# Processing Record 339 of Set 339 | uarini
# Processing Record 340 of Set 340 | gayny
# Processing Record 341 of Set 341 | karakendzha
# City not found. Skipping....
# Processing Record 342 of Set 342 | marsa matruh
# Processing Record 343 of Set 343 | san patricio
# Processing Record 344 of Set 344 | alofi
# Processing Record 345 of Set 345 | inuvik
# Processing Record 346 of Set 346 | norman wells
# Processing Record 347 of Set 347 | west lafayette
# Processing Record 348 of Set 348 | amaga
# Processing Record 349 of Set 349 | champerico
# Processing Record 350 of Set 350 | bosaso
# Processing Record 351 of Set 351 | teneguiban
# City not found. Skipping....
# Processing Record 352 of Set 352 | ancud
# Processing Record 353 of Set 353 | emerald
# Processing Record 354 of Set 354 | kremenki
# Processing Record 355 of Set 355 | winnemucca
# Processing Record 356 of Set 356 | den helder
# Processing Record 357 of Set 357 | north versailles
# Processing Record 358 of Set 358 | birjand
# Processing Record 359 of Set 359 | longyan
# Processing Record 360 of Set 360 | burnie
# Processing Record 361 of Set 361 | hasaki
# Processing Record 362 of Set 362 | kununurra
# Processing Record 363 of Set 363 | dhola
# Processing Record 364 of Set 364 | orlik
# Processing Record 365 of Set 365 | cao bang
# Processing Record 366 of Set 366 | fortuna
# Processing Record 367 of Set 367 | oga
# Processing Record 368 of Set 368 | iqaluit
# Processing Record 369 of Set 369 | yumen
# Processing Record 370 of Set 370 | bambanglipuro
# Processing Record 371 of Set 371 | kaitangata
# Processing Record 372 of Set 372 | angoche
# Processing Record 373 of Set 373 | joutseno
# Processing Record 374 of Set 374 | praia
# Processing Record 375 of Set 375 | ponerihouen
# Processing Record 376 of Set 376 | palmer
# Processing Record 377 of Set 377 | balurghat
# Processing Record 378 of Set 378 | narsaq
# Processing Record 379 of Set 379 | villazon
# City not found. Skipping....
# Processing Record 380 of Set 380 | khash
# Processing Record 381 of Set 381 | dongsheng
# Processing Record 382 of Set 382 | soyo
# Processing Record 383 of Set 383 | bahia honda
# Processing Record 384 of Set 384 | phan thiet
# Processing Record 385 of Set 385 | ust-kuyga
# Processing Record 386 of Set 386 | juba
# Processing Record 387 of Set 387 | constitucion
# Processing Record 388 of Set 388 | brufut
# Processing Record 389 of Set 389 | serenje
# Processing Record 390 of Set 390 | dingle
# Processing Record 391 of Set 391 | tsihombe
# City not found. Skipping....
# Processing Record 392 of Set 392 | mbalmayo
# Processing Record 393 of Set 393 | kattivakkam
# Processing Record 394 of Set 394 | veraval
# Processing Record 395 of Set 395 | sicamous
# Processing Record 396 of Set 396 | malangwa
# Processing Record 397 of Set 397 | husavik
# Processing Record 398 of Set 398 | mutsamudu
# City not found. Skipping....
# Processing Record 399 of Set 399 | la ronge
# Processing Record 400 of Set 400 | san andres
# Processing Record 401 of Set 401 | hazorasp
# Processing Record 402 of Set 402 | okhotsk
# Processing Record 403 of Set 403 | kolondieba
# Processing Record 404 of Set 404 | alyangula
# Processing Record 405 of Set 405 | puerto escondido
# Processing Record 406 of Set 406 | kalengwa
# Processing Record 407 of Set 407 | joao pinheiro
# Processing Record 408 of Set 408 | aksha
# Processing Record 409 of Set 409 | ladnun
# Processing Record 410 of Set 410 | kailua
# Processing Record 411 of Set 411 | anupgarh
# Processing Record 412 of Set 412 | severodvinsk
# Processing Record 413 of Set 413 | port-gentil
# Processing Record 414 of Set 414 | marawi
# Processing Record 415 of Set 415 | tete
# Processing Record 416 of Set 416 | ondorhaan
# City not found. Skipping....
# Processing Record 417 of Set 417 | metro
# Processing Record 418 of Set 418 | tucumcari
# Processing Record 419 of Set 419 | kokopo
# Processing Record 420 of Set 420 | glendive
# Processing Record 421 of Set 421 | lazaro cardenas
# Processing Record 422 of Set 422 | manutuke
# Processing Record 423 of Set 423 | boffa
# Processing Record 424 of Set 424 | port lavaca
# Processing Record 425 of Set 425 | evensk
# Processing Record 426 of Set 426 | kuala pilah
# Processing Record 427 of Set 427 | tooele
# Processing Record 428 of Set 428 | emborion
# Processing Record 429 of Set 429 | ostrovnoy
# Processing Record 430 of Set 430 | adrar
# Processing Record 431 of Set 431 | salinopolis
# Processing Record 432 of Set 432 | astana
# Processing Record 433 of Set 433 | itarema
# Processing Record 434 of Set 434 | paamiut
# Processing Record 435 of Set 435 | college
# Processing Record 436 of Set 436 | korla
# City not found. Skipping....
# Processing Record 437 of Set 437 | dolbeau
# City not found. Skipping....
# Processing Record 438 of Set 438 | hays
# Processing Record 439 of Set 439 | saleaula
# City not found. Skipping....
# Processing Record 440 of Set 440 | lugovskiy
# City not found. Skipping....
# Processing Record 441 of Set 441 | sorland
# Processing Record 442 of Set 442 | vigrestad
# Processing Record 443 of Set 443 | awjilah
# Processing Record 444 of Set 444 | biloela
# Processing Record 445 of Set 445 | hovd
# Processing Record 446 of Set 446 | thinadhoo
# Processing Record 447 of Set 447 | kananga
# Processing Record 448 of Set 448 | kharitonovo
# Processing Record 449 of Set 449 | saint-pierre
# Processing Record 450 of Set 450 | yendi
# Processing Record 451 of Set 451 | nouadhibou
# Processing Record 452 of Set 452 | rancharia
# Processing Record 453 of Set 453 | salinas
# Processing Record 454 of Set 454 | santiago del estero
# Processing Record 455 of Set 455 | bangolo
# Processing Record 456 of Set 456 | alamosa
# Processing Record 457 of Set 457 | bulgan
# Processing Record 458 of Set 458 | ahuimanu
# Processing Record 459 of Set 459 | ibadan
# Processing Record 460 of Set 460 | diffa
# Processing Record 461 of Set 461 | banff
# Processing Record 462 of Set 462 | kondinskoye
# Processing Record 463 of Set 463 | kjollefjord
# Processing Record 464 of Set 464 | pitimbu
# Processing Record 465 of Set 465 | manokwari
# Processing Record 466 of Set 466 | providencia
# Processing Record 467 of Set 467 | whitianga
# Processing Record 468 of Set 468 | pokrovsk-uralskiy
# City not found. Skipping....
# Processing Record 469 of Set 469 | sitka
# Processing Record 470 of Set 470 | huarmey
# Processing Record 471 of Set 471 | srednekolymsk
# Processing Record 472 of Set 472 | axim
# Processing Record 473 of Set 473 | monrovia
# Processing Record 474 of Set 474 | mukhen
# Processing Record 475 of Set 475 | manono
# Processing Record 476 of Set 476 | sarahan
# Processing Record 477 of Set 477 | bud
# Processing Record 478 of Set 478 | santa fe
# Processing Record 479 of Set 479 | cap-aux-meules
# Processing Record 480 of Set 480 | copiapo
# Processing Record 481 of Set 481 | sayyan
# Processing Record 482 of Set 482 | chumikan
# Processing Record 483 of Set 483 | lyuban
# Processing Record 484 of Set 484 | nenjiang
# Processing Record 485 of Set 485 | margate
# Processing Record 486 of Set 486 | coquimbo
# Processing Record 487 of Set 487 | la libertad
# Processing Record 488 of Set 488 | gravdal
# Processing Record 489 of Set 489 | leningradskiy
# Processing Record 490 of Set 490 | nyurba
# Processing Record 491 of Set 491 | raudeberg
# Processing Record 492 of Set 492 | heinola
# Processing Record 493 of Set 493 | udachnyy
# Processing Record 494 of Set 494 | kupang
# Processing Record 495 of Set 495 | barawe
# City not found. Skipping....
# Processing Record 496 of Set 496 | newport
# Processing Record 497 of Set 497 | kantunilkin
# Processing Record 498 of Set 498 | turukhansk
# Processing Record 499 of Set 499 | ratlam
# Processing Record 500 of Set 500 | havre-saint-pierre
# Processing Record 501 of Set 501 | san rafael
# Processing Record 502 of Set 502 | yadgir
# Processing Record 503 of Set 503 | oranjestad
# Processing Record 504 of Set 504 | sechura
# Processing Record 505 of Set 505 | baruun-urt
# Processing Record 506 of Set 506 | yongan
# Processing Record 507 of Set 507 | shelburne
# Processing Record 508 of Set 508 | watertown
# Processing Record 509 of Set 509 | malakal
# City not found. Skipping....
# Processing Record 510 of Set 510 | tomatlan
# Processing Record 511 of Set 511 | bathsheba
# Processing Record 512 of Set 512 | namwala
# Processing Record 513 of Set 513 | shetpe
# Processing Record 514 of Set 514 | klaksvik
# Processing Record 515 of Set 515 | sinnamary
# Processing Record 516 of Set 516 | aleksandrov gay
# Processing Record 517 of Set 517 | leirvik
# Processing Record 518 of Set 518 | jackson
# Processing Record 519 of Set 519 | mount gambier
# Processing Record 520 of Set 520 | plettenberg bay
# Processing Record 521 of Set 521 | la baule-escoublac
# Processing Record 522 of Set 522 | ivanava
# Processing Record 523 of Set 523 | grevesmuhlen
# Processing Record 524 of Set 524 | mendi
# Processing Record 525 of Set 525 | volksrust
# Processing Record 526 of Set 526 | henties bay
# Processing Record 527 of Set 527 | ampanihy
# Processing Record 528 of Set 528 | sistranda
# Processing Record 529 of Set 529 | ciras
# City not found. Skipping....
# Processing Record 530 of Set 530 | lompoc
# Processing Record 531 of Set 531 | ajdabiya
# Processing Record 532 of Set 532 | mrirt
# City not found. Skipping....
# Processing Record 533 of Set 533 | arraial do cabo
# Processing Record 534 of Set 534 | tawkar
# City not found. Skipping....
# Processing Record 535 of Set 535 | matamoros
# Processing Record 536 of Set 536 | kambove
# Processing Record 537 of Set 537 | ozernovskiy
# Processing Record 538 of Set 538 | arlit
# Processing Record 539 of Set 539 | dunedin
# Processing Record 540 of Set 540 | corralillo
# Processing Record 541 of Set 541 | rungata
# City not found. Skipping....
# Processing Record 542 of Set 542 | kurchum
# Processing Record 543 of Set 543 | lorengau
# Processing Record 544 of Set 544 | liyang
# Processing Record 545 of Set 545 | rio pardo de minas
# Processing Record 546 of Set 546 | sumbawa
# City not found. Skipping....
# Processing Record 547 of Set 547 | biu
# Processing Record 548 of Set 548 | labutta
# City not found. Skipping....
# Processing Record 549 of Set 549 | dormidontovka
# Processing Record 550 of Set 550 | kenai
# Processing Record 551 of Set 551 | shenzhen
# Processing Record 552 of Set 552 | mandalgovi
# Processing Record 553 of Set 553 | chifeng
# Processing Record 554 of Set 554 | beatrice
# Processing Record 555 of Set 555 | saint anthony
# Processing Record 556 of Set 556 | kodinsk
# Processing Record 557 of Set 557 | flinders
# Processing Record 558 of Set 558 | tumpat
# Processing Record 559 of Set 559 | weligama
# Processing Record 560 of Set 560 | toliary
# City not found. Skipping....
# Processing Record 561 of Set 561 | petropavlovsk-kamchatskiy
# Processing Record 562 of Set 562 | astoria
# Processing Record 563 of Set 563 | ferrol
# Processing Record 564 of Set 564 | gobabis
# Processing Record 565 of Set 565 | codrington
# Processing Record 566 of Set 566 | kemin
# Processing Record 567 of Set 567 | ngunguru
# Processing Record 568 of Set 568 | ust-ilimsk
# Processing Record 569 of Set 569 | fairbanks
# Processing Record 570 of Set 570 | bulalacao
# Processing Record 571 of Set 571 | van
# Processing Record 572 of Set 572 | wasilla
# Processing Record 573 of Set 573 | gualeguaychu
# Processing Record 574 of Set 574 | gat
# Processing Record 575 of Set 575 | usinsk
# Processing Record 576 of Set 576 | tasbuget
# City not found. Skipping....
# Processing Record 577 of Set 577 | cariacica
# Processing Record 578 of Set 578 | luan
# Processing Record 579 of Set 579 | shishou
# Processing Record 580 of Set 580 | isla vista
# Processing Record 581 of Set 581 | darhan
# Processing Record 582 of Set 582 | fare
# Processing Record 583 of Set 583 | shimoda
# Processing Record 584 of Set 584 | manicore
# Processing Record 585 of Set 585 | yamada
# Processing Record 586 of Set 586 | kalmunai
# Processing Record 587 of Set 587 | rodrigues alves
# Processing Record 588 of Set 588 | sabang
# Processing Record 589 of Set 589 | tornio
# Processing Record 590 of Set 590 | bandarbeyla
# Processing Record 591 of Set 591 | novosemeykino
# Processing Record 592 of Set 592 | truth or consequences
# Processing Record 593 of Set 593 | mantua
# Processing Record 594 of Set 594 | barabai
# Processing Record 595 of Set 595 | kinablangan
# Processing Record 596 of Set 596 | barra do garcas
# Processing Record 597 of Set 597 | shingu
# Processing Record 598 of Set 598 | carbonia
# Processing Record 599 of Set 599 | quatre cocos
# Processing Record 600 of Set 600 | lingyuan
# Processing Record 601 of Set 601 | svetlyy
# City not found. Skipping....
# Processing Record 602 of Set 602 | nantucket
# Processing Record 603 of Set 603 | broken hill
# Processing Record 604 of Set 604 | le port
# Processing Record 605 of Set 605 | vao
# Processing Record 606 of Set 606 | tilichiki
# Processing Record 607 of Set 607 | zdzieszowice
# Processing Record 608 of Set 608 | satrikh
# Processing Record 609 of Set 609 | golden
# Processing Record 610 of Set 610 | dakar
# Processing Record 611 of Set 611 | shaunavon
# Processing Record 612 of Set 612 | trinidad
# Processing Record 613 of Set 613 | bonthe
# Processing Record 614 of Set 614 | shieli
# Processing Record 615 of Set 615 | shar
# Processing Record 616 of Set 616 | barra do corda
# Processing Record 617 of Set 617 | bengkulu
# City not found. Skipping....
# Processing Record 618 of Set 618 | warqla
# City not found. Skipping....
# Processing Record 619 of Set 619 | rongcheng
# Processing Record 620 of Set 620 | troitskoye
# Processing Record 621 of Set 621 | castel san giovanni
# Processing Record 622 of Set 622 | pascagoula
# Processing Record 623 of Set 623 | hambantota
# Processing Record 624 of Set 624 | kulhudhuffushi
# Processing Record 625 of Set 625 | kendari
# Processing Record 626 of Set 626 | mackay
# Processing Record 627 of Set 627 | ahipara
# Processing Record 628 of Set 628 | egersund
# Processing Record 629 of Set 629 | ranong
# Processing Record 630 of Set 630 | jining
# Processing Record 631 of Set 631 | rawson
# Processing Record 632 of Set 632 | inta
# Processing Record 633 of Set 633 | leh
# Processing Record 634 of Set 634 | aripuana
# Processing Record 635 of Set 635 | narrabri
# Processing Record 636 of Set 636 | ulaangom
# Done

# %%
cities_df.head()
# Out:
#              Name country latitude longitude max temperature cloudiness  \
# 0         mataura      NZ   -46.19    168.86         280.111         92
# 1       hithadhoo      MV     -0.6     73.08         300.861         92
# 2          tekeli      KZ    44.86     78.76         283.261          0
# 3  saint-augustin      FR    44.83     -0.61          297.15          0
# 4      bredasdorp      ZA   -34.53     20.04          292.15          0
#
#          date humidity wind speed
# 0  1538231545       97       1.11
# 1  1538231548      100       4.11
# 2  1538231551       60       1.66
# 3  1538229600       38        2.6
# 4  1538229600       48        7.7

# %%
cities_df.to_csv("JMCityoutput.csv")

# %%
cities_df.count()
# Out:
# Name               637
# country            637
# latitude           637
# longitude          637
# max temperature    637
# cloudiness         637
# date               637
# humidity           637
# wind speed         637
# dtype: int64

# %%
cities_df.dtypes
# Out:
# Name               object
# country            object
# latitude           object
# longitude          object
# max temperature    object
# cloudiness         object
# date               object
# humidity           object
# wind speed         object
# dtype: object

# %%
city_rec = pd.read_csv("JMcityoutput.csv")
city_rec.head()
# Out:
#    Unnamed: 0            Name country  latitude  longitude  max temperature  \
# 0           0         mataura      NZ    -46.19     168.86          280.111
# 1           1       hithadhoo      MV     -0.60      73.08          300.861
# 2           2          tekeli      KZ     44.86      78.76          283.261
# 3           3  saint-augustin      FR     44.83      -0.61          297.150
# 4           4      bredasdorp      ZA    -34.53      20.04          292.150
#
#    cloudiness          date  humidity  wind speed
# 0        92.0  1.538232e+09      97.0        1.11
# 1        92.0  1.538232e+09     100.0        4.11
# 2         0.0  1.538232e+09      60.0        1.66
# 3         0.0  1.538230e+09      38.0        2.60
# 4         0.0  1.538230e+09      48.0        7.70

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
lat = city_rec["latitude"]
humid = city_rec["humidity"]
clouds = city_rec["cloudiness"]
max_temp = city_rec["max temperature"]
wind = city_rec["wind speed"]

# %%
plt.scatter(lat, max_temp, marker = "o", color = "skyblue", alpha = .75, edgecolors = "black")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title("City Latitude vs. Max Temperature (08/22/18)")
plt.grid(True)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat, humid, marker = "o", color = "blue", alpha = .75, edgecolors = "black")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs Humidity (08/22/18)")
# Out:
# Text(0.5,1,'City Latitude vs Humidity (08/22/18)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat, clouds, marker = "o", color = "lightblue", alpha = .9, edgecolors = "black")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs Cloudiness (08/22/18)")
# Out:
# Text(0.5,1,'City Latitude vs Cloudiness (08/22/18)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat, wind, marker = "o", color = "green", alpha = .75, edgecolors = "black")
plt.grid(True)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitude vs Wind Speed (08/22/18)")
# Out:
# Text(0.5,1,'City Latitude vs Wind Speed (08/22/18)')
